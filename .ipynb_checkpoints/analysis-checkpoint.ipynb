# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Task 1: Load and Explore Data Distribution
df = pd.read_csv('Sample - Superstore.csv')

# Summary statistics for relevant columns
summary_stats = df[['Ship Mode', 'Segment', 'City', 'Sales', 'Quantity', 'Discount', 'Profit']].describe()

# Visualizations
plt.figure(figsize=(15, 8))

# Visualize Ship Mode distribution
plt.subplot(231)
sns.countplot(data=df, x='Ship Mode')
plt.title('Distribution of Ship Mode')

# Visualize Segment distribution
plt.subplot(232)
sns.countplot(data=df, x='Segment')
plt.title('Distribution of Segment')

# Visualize City distribution (consider top cities)
plt.subplot(233)
top_cities = df['City'].value_counts().head(10)
sns.barplot(x=top_cities.index, y=top_cities.values)
plt.xticks(rotation=90)
plt.title('Top 10 Cities by Sales')

# Visualize Sales, Quantity, Discount, and Profit distributions
plt.subplot(234)
sns.histplot(data=df, x='Sales', bins=30, kde=True)
plt.title('Sales Distribution')

plt.subplot(235)
sns.histplot(data=df, x='Quantity', bins=30, kde=True)
plt.title('Quantity Distribution')

plt.subplot(236)
sns.histplot(data=df, x='Discount', bins=30, kde=True)
plt.title('Discount Distribution')


plt.show()
# Out:
# C:\Users\Lumiti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lumiti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lumiti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lumiti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
# Task 2: Explore Differences between Subsets
subset1 = df[df['Quantity'] < 5]
subset2 = df[df['Quantity'] >= 5]

plt.figure(figsize=(12, 5))

# Visualize Sales distribution for each subset
plt.subplot(121)
sns.histplot(data=subset1, x='Sales', bins=30, kde=True, color='blue', label='<5 Quantity')
plt.title('Sales Distribution for Quantity < 5')
plt.legend()

plt.subplot(122)
sns.histplot(data=subset2, x='Sales', bins=30, kde=True, color='green', label='>=5 Quantity')
plt.title('Sales Distribution for Quantity >= 5')
plt.legend()

plt.show()
# Out:
# C:\Users\Lumiti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lumiti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lumiti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Task 3: Explore Correlations
correlation_matrix = df.corr()

# Find features with the strongest positive and negative correlations with Sales
strong_positive_corr = correlation_matrix['Sales'].sort_values(ascending=False).head(3)
strong_negative_corr = correlation_matrix['Sales'].sort_values(ascending=True).head(3)

# Visualize the relationships
plt.figure(figsize=(8, 6))
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Task 3: Explore Correlations
# ----> 2 correlation_matrix = df.corr()
#       4 # Find features with the strongest positive and negative correlations with Sales
#       5 strong_positive_corr = correlation_matrix['Sales'].sort_values(ascending=False).head(3)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# ...

# %%
# Task 4: Engineer and Explore a New Feature
df['Profit_Discount_Diff'] = df['Profit'] - df['Discount']

plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Profit_Discount_Diff', y='Sales', alpha=0.5)
plt.title('Profit-Discount Difference vs. Sales')
# Out:
# C:\Users\Lumiti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lumiti\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Profit-Discount Difference vs. Sales')
